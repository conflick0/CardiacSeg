# %%
# mount driver
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/CardiacSeg/dataset/nnUNet

# install dependents
# !pip install -q nnunet
# !pip install -q "monai-weekly[nibabel, tqdm, einops]"
# !python -c "import matplotlib" || pip install -q matplotlib
# %matplotlib inline

# sync python module
# %load_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1jz_DGnICBmKWCr_JL904PDQdIEK0_EQG/CardiacSeg/dataset/nnUNet
#      |████████████████████████████████| 251 kB 15.0 MB/s
#      |████████████████████████████████| 43 kB 2.1 MB/s
#      |████████████████████████████████| 151 kB 76.8 MB/s
#      |████████████████████████████████| 61 kB 437 kB/s
#      |████████████████████████████████| 52.8 MB 221 kB/s
#      |████████████████████████████████| 96 kB 7.2 MB/s
#      |████████████████████████████████| 2.0 MB 77.1 MB/s
#      |████████████████████████████████| 12.9 MB 63.6 MB/s
#   Building wheel for nnunet (setup.py) ... done
#   Building wheel for batchgenerators (setup.py) ... done
#   Building wheel for medpy (setup.py) ... done
#   Building wheel for sklearn (setup.py) ... done
#      |████████████████████████████████| 1.1 MB 36.9 MB/s

# %%
# !pip install -q nnunet

# %%
import sys
# set package path
sys.path.append("/content/drive/MyDrive/CardiacSeg")

import os
from pathlib import PurePath

from monai.transforms import (
    Compose,
    LoadImaged,
)
from nnunet.dataset_conversion.utils import generate_dataset_json 

from data_utils.nnunet_dataset import get_nnunet_data_dicts
from data_utils.segthor_dataset import get_data_dicts, convert_to_nnunet_dataset
from transforms.segthor_transform import save_transform_lbl

from data_utils.visualization import show_img_lbl
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet

# %%
# !gdown --id 1RzPB1_bqzQhlWvU-YGvZzhx2omcDh38C
# !tar -xvf Task04_Hippocampus.tar

# %% [markdown]
# ## Config

# %%
# %env nnUNet_raw_data_base=/content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_raw_data_base
# %env nnUNet_preprocessed=/content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed
# %env RESULTS_FOLDER=/content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_trained_models
# Out:
# env: nnUNet_raw_data_base=/content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_raw_data_base
# env: nnUNet_preprocessed=/content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed
# env: RESULTS_FOLDER=/content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_trained_models

# %%
task_name = 'Task501_SegTHOR'
data_dir = '/content/drive/MyDrive/CardiacSeg/dataset/SegTHOR/train'
dst_data_dir = f'/content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/{task_name}'
data_json_pth = os.path.join(dst_data_dir, 'dataset.json')
imagesTr_pth = os.path.join(dst_data_dir, 'imagesTr')
imagesTs_pth = os.path.join(dst_data_dir, 'imagesTs')

# %% [markdown]
# ## Convert decathlon task

# %%
# !nnUNet_convert_decathlon_task -i Task04_Hippocampus
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet

# %% [markdown]
# ## Experiment planning and preprocessing

# %%
# !nnUNet_plan_and_preprocess -t 4 --verify_dataset_integrity
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# before crop: (1, 34, 51, 36) after crop: (1, 34, 51, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 51, 37) after crop: (1, 33, 51, 37) spacing: [1. 1. 1.]
#
# hippocampus_321
# hippocampus_333
# before crop: (1, 38, 46, 35) after crop: (1, 38, 46, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 27, 53, 38) after crop: (1, 27, 53, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 51, 38) after crop: (1, 37, 51, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 53, 36) after crop: (1, 37, 53, 36) spacing: [1. 1. 1.]
#
# hippocampus_374
# hippocampus_194
# hippocampus_219
# hippocampus_008
# before crop: (1, 29, 49, 34) after crop: (1, 29, 49, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 48, 35) after crop: (1, 40, 48, 35) spacing: [1. 1. 1.]
#
# hippocampus_287
# hippocampus_260
# before crop: (1, 34, 46, 34) after crop: (1, 34, 46, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 46, 33) after crop: (1, 38, 46, 33) spacing: [1. 1. 1.]
#
# hippocampus_221
# hippocampus_250
# before crop: (1, 39, 45, 37) after crop: (1, 39, 45, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 30, 50, 35) after crop: (1, 30, 50, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 39, 48, 38) after crop: (1, 39, 48, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 48, 36) after crop: (1, 40, 48, 36) spacing: [1. 1. 1.]
#
# hippocampus_319
# before crop: (1, 39, 50, 37) after crop: (1, 39, 50, 37) spacing: [1. 1. 1.]
#
# hippocampus_223
# hippocampus_143
# hippocampus_274
# before crop: (1, 29, 53, 35) after crop: (1, 29, 53, 35) spacing: [1. 1. 1.]
#
# hippocampus_360
# hippocampus_130
# before crop: (1, 34, 48, 32) after crop: (1, 34, 48, 32) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 51, 35) after crop: (1, 36, 51, 35) spacing: [1. 1. 1.]
#
# hippocampus_096
# hippocampus_350
# before crop: (1, 34, 48, 33) after crop: (1, 34, 48, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 52, 35) after crop: (1, 37, 52, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 41, 45, 32) after crop: (1, 41, 45, 32) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 40, 35) after crop: (1, 40, 40, 35) spacing: [1. 1. 1.]
#
# hippocampus_207
# before crop: (1, 37, 49, 34) after crop: (1, 37, 49, 34) spacing: [1. 1. 1.]
#
# hippocampus_094
# hippocampus_389
# hippocampus_309
# hippocampus_203
# before crop: (1, 40, 49, 35) after crop: (1, 40, 49, 35) spacing: [1. 1. 1.]
#
# hippocampus_387
# before crop: (1, 39, 47, 34) after crop: (1, 39, 47, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 49, 35) after crop: (1, 34, 49, 35) spacing: [1. 1. 1.]
#
# hippocampus_242
# hippocampus_378
# before crop: (1, 38, 50, 38) after crop: (1, 38, 50, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 53, 35) after crop: (1, 33, 53, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 52, 34) after crop: (1, 38, 52, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 49, 34) after crop: (1, 38, 49, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 49, 34) after crop: (1, 32, 49, 34) spacing: [1. 1. 1.]
#
# hippocampus_376
# hippocampus_067
# hippocampus_289
# hippocampus_252
# hippocampus_303
# before crop: (1, 32, 51, 33) after crop: (1, 32, 51, 33) spacing: [1. 1. 1.]
#
# hippocampus_053
# before crop: (1, 34, 52, 38) after crop: (1, 34, 52, 38) spacing: [1. 1. 1.]
#
# hippocampus_188
# before crop: (1, 34, 52, 35) after crop: (1, 34, 52, 35) spacing: [1. 1. 1.]
#
# hippocampus_205
# before crop: (1, 37, 55, 35) after crop: (1, 37, 55, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 41, 42, 36) after crop: (1, 41, 42, 36) spacing: [1. 1. 1.]
#
# hippocampus_004
# before crop: (1, 36, 49, 35) after crop: (1, 36, 49, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 48, 35) after crop: (1, 38, 48, 35) spacing: [1. 1. 1.]
#
# hippocampus_276
# before crop: (1, 26, 55, 37) after crop: (1, 26, 55, 37) spacing: [1. 1. 1.]
#
# hippocampus_297
# hippocampus_372
# hippocampus_352
# before crop: (1, 35, 51, 37) after crop: (1, 35, 51, 37) spacing: [1. 1. 1.]
#
# hippocampus_299
# before crop: (1, 36, 54, 37) after crop: (1, 36, 54, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 47, 32) after crop: (1, 32, 47, 32) spacing: [1. 1. 1.]
#
# hippocampus_088
# hippocampus_305
# before crop: (1, 38, 52, 36) after crop: (1, 38, 52, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 50, 35) after crop: (1, 33, 50, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 30, 51, 34) after crop: (1, 30, 51, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 50, 36) after crop: (1, 34, 50, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 51, 38) after crop: (1, 35, 51, 38) spacing: [1. 1. 1.]
#
# hippocampus_104
# hippocampus_368
# hippocampus_020
# hippocampus_311
# hippocampus_098
# before crop: (1, 34, 54, 32) after crop: (1, 34, 54, 32) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 52, 40) after crop: (1, 35, 52, 40) spacing: [1. 1. 1.]
#
# before crop: (1, 30, 49, 34) after crop: (1, 30, 49, 34) spacing: [1. 1. 1.]
#
# hippocampus_244
# hippocampus_155
# hippocampus_126
# before crop: (1, 39, 53, 35) after crop: (1, 39, 53, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 55, 38) after crop: (1, 40, 55, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 49, 37) after crop: (1, 37, 49, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 43, 46, 36) after crop: (1, 43, 46, 36) spacing: [1. 1. 1.]
#
# hippocampus_149
# before crop: (1, 34, 48, 37) after crop: (1, 34, 48, 37) spacing: [1. 1. 1.]
#
# hippocampus_337
# before crop: (1, 37, 53, 34) after crop: (1, 37, 53, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 30, 53, 38) after crop: (1, 30, 53, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 43, 44, 39) after crop: (1, 43, 44, 39) spacing: [1. 1. 1.]
#
# hippocampus_036
# hippocampus_327
# hippocampus_026
# before crop: (1, 32, 49, 33) after crop: (1, 32, 49, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 41, 44, 33) after crop: (1, 41, 44, 33) spacing: [1. 1. 1.]
#
# hippocampus_057
# hippocampus_229
# before crop: (1, 39, 47, 36) after crop: (1, 39, 47, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 27, 54, 36) after crop: (1, 27, 54, 36) spacing: [1. 1. 1.]
#
# hippocampus_136
# hippocampus_190
# before crop: (1, 36, 50, 36) after crop: (1, 36, 50, 36) spacing: [1. 1. 1.]
#
# hippocampus_138
# before crop: (1, 34, 51, 35) after crop: (1, 34, 51, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 50, 33) after crop: (1, 35, 50, 33) spacing: [1. 1. 1.]
#
# hippocampus_157
# hippocampus_329
# before crop: (1, 41, 49, 34) after crop: (1, 41, 49, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 30, 52, 37) after crop: (1, 30, 52, 37) spacing: [1. 1. 1.]
#
# hippocampus_381
# before crop: (1, 42, 46, 32) after crop: (1, 42, 46, 32) spacing: [1. 1. 1.]
#
# hippocampus_227
# hippocampus_038
# before crop: (1, 35, 51, 36) after crop: (1, 35, 51, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 53, 34) after crop: (1, 32, 53, 34) spacing: [1. 1. 1.]
#
# hippocampus_102
# hippocampus_354
# before crop: (1, 37, 49, 33) after crop: (1, 37, 49, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 47, 36) after crop: (1, 36, 47, 36) spacing: [1. 1. 1.]
#
# hippocampus_393
# hippocampus_090
# before crop: (1, 35, 51, 37) after crop: (1, 35, 51, 37) spacing: [1. 1. 1.]
#
# hippocampus_145
# before crop: (1, 32, 55, 36) after crop: (1, 32, 55, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 50, 36) after crop: (1, 32, 50, 36) spacing: [1. 1. 1.]
#
# hippocampus_161
# before crop: (1, 31, 51, 36) after crop: (1, 31, 51, 36) spacing: [1. 1. 1.]
#
# hippocampus_325
# before crop: (1, 40, 50, 37) after crop: (1, 40, 50, 37) spacing: [1. 1. 1.]
#
# hippocampus_124
# hippocampus_356
# before crop: (1, 33, 53, 36) after crop: (1, 33, 53, 36) spacing: [1. 1. 1.]
#
# hippocampus_045
# before crop: (1, 36, 51, 35) after crop: (1, 36, 51, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 51, 35) after crop: (1, 40, 51, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 41, 55, 35) after crop: (1, 41, 55, 35) spacing: [1. 1. 1.]
#
# hippocampus_173
# before crop: (1, 37, 51, 36) after crop: (1, 37, 51, 36) spacing: [1. 1. 1.]
#
# hippocampus_225
# hippocampus_024
# hippocampus_235
# before crop: (1, 37, 48, 36) after crop: (1, 37, 48, 36) spacing: [1. 1. 1.]
#
# hippocampus_034
# before crop: (1, 32, 53, 35) after crop: (1, 32, 53, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 26, 53, 33) after crop: (1, 26, 53, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 52, 38) after crop: (1, 33, 52, 38) spacing: [1. 1. 1.]
#
# hippocampus_370
# hippocampus_092
# before crop: (1, 35, 58, 37) after crop: (1, 35, 58, 37) spacing: [1. 1. 1.]
#
# hippocampus_171
# before crop: (1, 40, 49, 36) after crop: (1, 40, 49, 36) spacing: [1. 1. 1.]
#
# hippocampus_335
# hippocampus_383
# before crop: (1, 28, 49, 38) after crop: (1, 28, 49, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 50, 35) after crop: (1, 36, 50, 35) spacing: [1. 1. 1.]
#
# hippocampus_358
# hippocampus_301
# before crop: (1, 28, 56, 35) after crop: (1, 28, 56, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 41, 47, 32) after crop: (1, 41, 47, 32) spacing: [1. 1. 1.]
#
# hippocampus_163
# hippocampus_248
# before crop: (1, 29, 55, 33) after crop: (1, 29, 55, 33) spacing: [1. 1. 1.]
#
# hippocampus_049
# before crop: (1, 34, 50, 35) after crop: (1, 34, 50, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 50, 31) after crop: (1, 36, 50, 31) spacing: [1. 1. 1.]
#
# hippocampus_180
# before crop: (1, 44, 47, 36) after crop: (1, 44, 47, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 50, 36) after crop: (1, 38, 50, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 51, 35) after crop: (1, 36, 51, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 45, 37) after crop: (1, 36, 45, 37) spacing: [1. 1. 1.]
#
#
#
#
#  Task004_Hippocampus
# number of threads:  (8, 8)
#
# not using nonzero mask for normalization
# Are we using the nonzero mask for normalizaion? OrderedDict([(0, False)])
# the median shape of the dataset is  [36. 50. 35.]
# the max shape in the dataset is  [47. 59. 43.]
# the min shape in the dataset is  [24. 40. 31.]
# we don't want feature maps smaller than  4  in the bottleneck
# the transposed median shape of the dataset is  [36. 50. 35.]
# generating configuration for 3d_fullres
# {0: {'batch_size': 9, 'num_pool_per_axis': [3, 3, 3], 'patch_size': array([40, 56, 40]), 'median_patient_size_in_voxels': array([36, 50, 35]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': False, 'pool_op_kernel_sizes': [[2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}}
# transpose forward [0, 1, 2]
# transpose backward [0, 1, 2]
# Initializing to run preprocessing
# npz folder: /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_raw_data_base/nnUNet_cropped_data/Task004_Hippocampus
# output_folder: /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 47, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 47, 35)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 48, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 48, 35)}
#
# 1 2135
# 1 1867
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 35)}
#
# 1 1324
# 2 1583
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_035.npz
# 2 1343
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_017.npz
# 2 1624
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_001.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 51, 35)}
#
# 1 1390
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 48, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 48, 36)}
#
# 1 1246
# 2 1622
# 2 1383
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_045.npz
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_057.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 55, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 55, 36)}
#
# 1 2289
# 2 1666
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_102.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 28, 49, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 28, 49, 38)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 47, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 47, 32)}
#
# 1 1488
# 1 1222
# 2 1826
# 2 1654
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_075.npz
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_092.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 47, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 47, 36)}
# no resampling necessary
# no resampling necessary
#
# 1 1888
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 47, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 47, 36)}
#
# 1 1849
# 2 1468
# 2 1660
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_019.npz
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_036.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 52, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 52, 34)}
#
# 1 1550
# 2 1803
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_003.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 49, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 49, 36)}
#
# 1 1611
# 2 1681
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_046.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 36, 53, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 36, 53, 34)}
#
# 1 1334
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 53, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 53, 35)}
#
# 1 2221
# no resampling necessary
# no resampling necessary
# 2 1793
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 45, 47, 35)}
# after: saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_058.npz
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 45, 47, 35)}
#
# 2 1596
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_104.npz
# 1 1984
# 2 1734
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_077.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 53, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 53, 34)}
#
# 1 1762
# 2 1980
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_093.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 51, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 51, 34)}
#
# 1 1578
# 2 1617
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_037.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 43, 46, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 43, 46, 36)}
#
# 1 2146
# 2 1465
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_020.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 52, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 52, 36)}
#
# 1 1832
# 2 1866
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_004.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 29, 52, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 29, 52, 38)}
#
# 1 1957
# 2 1315
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_048.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 52, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 52, 33)}
#
# 1 1650
# 2 1721
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_083.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 31, 52, 39)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 31, 52, 39)}
#
# 1 1726
# 2 1683
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_060.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 35)}
#
# 1 1748
# 2 1820
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_023.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 47, 33)}
# after: no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 52, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 52, 35)}
#
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 47, 33)}
#
# 1 2314
# 2 1949
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_006.npz
# 1 1832
# 2 1328
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_105.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 37)}
#
# 1 1837
# 2 1721
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_038.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 50, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 50, 38)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 36, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 36, 51, 35)}
#
# 1 2362
# 2 1667
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_094.npz
# 1 1908
# 2 1820
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_049.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 52, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 52, 34)}
#
# 1 1390
# 2 1760
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_084.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 53, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 53, 35)}
#
# 1 2044
# 2 1616
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_064.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 52, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 52, 38)}
#
# 1 2011
# 2 2019
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_024.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 47, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 47, 34)}
#
# 1 1842
# 2 1530
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_007.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 46, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 46, 34)}
#
# 1 1712
# 2 1380
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_106.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 49, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 49, 38)}
#
# 1 2023
# 2 1808
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_050.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 53, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 53, 34)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 49, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 49, 34)}
#
# 1 2038
# 2 1620
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_039.npz
# 1 2191
# 2 1594
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_095.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 52, 39)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 52, 39)}
#
# 1 1730
# 2 1920
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_065.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 55, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 55, 35)}
#
# 1 1933
# 2 1774
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_087.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 54, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 54, 33)}
#
# 1 1521
# 2 1588
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_051.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 48, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 48, 36)}
#
# 1 1725
# 2 1523
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_008.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 55, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 55, 35)}
#
# 1 1911
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 48, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 48, 35)}
#
# 1 1896
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 47, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 47, 34)}
#
# 2 1430
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_025.npz
# 2 2035
# 1 1890
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_107.npz
# 2 1450
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_096.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 52, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 52, 36)}
#
# 1 1906
# 2 1539
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_040.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 52, 40)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 52, 40)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 42, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 42, 36)}
#
# 1 2110
# 1 1521
# 2 1290
# 2 1768
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_067.npz
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_088.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 52, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 52, 34)}
#
# 1 1847
# 2 1514
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 48, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 48, 37)}
#
# 1 1354
# 2 1399
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_097.npz
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_052.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 31, 50, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 31, 50, 36)}
#
# 1 1912
# 2 1544
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_011.npz
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 36, 50, 36)}
# after: before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 53, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 36, 50, 36)}
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 53, 36)}
#
#
# 1 2059
# 1 1863
# 2 1765
# 2 1881
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_026.npz
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_108.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 51, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 51, 34)}
#
# 1 1725
# 2 1961
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_089.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 51, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 51, 36)}
#
# 1 1777
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 50, 37)}
# after: 2 1986
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 50, 37)}
#
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_041.npz
# 1 2044
# 2 1957
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_090.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 43, 40, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 43, 40, 36)}
#
# 1 1733
# 2 1267
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_068.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 48, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 48, 37)}
#
# 1 1515
# 2 1375
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_098.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 37)}
#
# 1 1650
# 2 1869
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_053.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 50, 39)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 50, 39)}
#
# 1 2017
# 2 1605
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_014.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 29, 51, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 29, 51, 36)}
#
# 1 1389
# 2 1672
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_091.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 48, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 48, 33)}
#
# 1 1855
# 2 1568
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_033.npz
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 52, 37)}
# after: before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 36, 49, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 52, 37)}
# no resampling necessary
# no resampling necessary
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 36, 49, 36)}
#
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 27, 52, 33)}
# after:
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 27, 52, 33)}
#
# 1 1252
# 2 1283
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_099.npz
# 1 1589
# 1 1871
# 2 1976
# 2 1630
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_109.npz
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_042.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 42, 47, 41)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 42, 47, 41)}
#
# 1 1965
# 2 1768
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_056.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 50, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 50, 37)}
#
# 1 1895
# 2 1555
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_070.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 55, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 55, 35)}
#
# 1 1606
# 2 1531
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_124.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 28, 51, 42)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 28, 51, 42)}
#
# 1 1511
# 2 1308
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_015.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 52, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 52, 36)}
#
# 1 1888
# 2 1706
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_101.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 49, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 49, 36)}
#
# 1 1830
# 2 1545
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_034.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 50, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 50, 38)}
#
# 1 2459
# 2 1245
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_114.npz
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 48, 38)}
# after: no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 42, 47, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 48, 38)}
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 42, 47, 37)}
#
# 1 1692
#
# 1 1438
# 2 1528
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_044.npz
# 2 1562
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_074.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 42, 46, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 42, 46, 32)}
#
# 1 1171
# 2 1363
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_138.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 49, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 49, 37)}
#
# 1 1605
# 2 1483
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_150.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 42, 43)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 42, 43)}
#
# 1 1657
# 2 1069
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_125.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 51, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 51, 38)}
#
# 1 1800
# 2 1620
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_162.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 53, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 53, 32)}
#
# 1 1712
# 2 1517
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_123.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 53, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 53, 35)}
#
# 1 1539
# 2 2018
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_173.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 49, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 49, 35)}
#
# 1 1841
# 2 1272
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_185.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 49, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 49, 34)}
#
# 1 1526
# 2 1301
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_203.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 42, 44, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 42, 44, 33)}
#
# 1 1235
# 2 1479
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_141.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 53, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 53, 36)}
#
# 1 2121
# 2 1873
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_152.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 43, 44, 39)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 43, 44, 39)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 44, 47, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 44, 47, 36)}
#
# 1 1650
# 2 1495
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_126.npz
# 1 1569
# 2 1934
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_163.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 45, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 45, 37)}
#
# 1 1538
# 2 1292
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_219.npz
# no resampling necessary
# no resampling necessary
# ...
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 49, 35)}
#
# normalization...
# normalization done
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 36, 47, 34)}
#
# normalization...
# normalization done
# 1 1262
# 1 1242
# 2 1436
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_334.npz
# 2 1372
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_359.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 48, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 48, 35)}
#
# normalization...
# normalization done
# 1 2113
# 2 1284
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_385.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 49, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 49, 34)}
#
# normalization...
# normalization done
# 1 1882
# 2 1807
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_373.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 49, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 49, 35)}
#
# normalization...
# normalization done
# 1 1475
# 2 1467
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_350.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 49, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 49, 34)}
#
# normalization...
# normalization done
# 1 1298
# 2 1633
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_360.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 47, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 47, 32)}
#
# normalization...
# normalization done
# 1 1263
# 2 1269
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_335.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 45, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 45, 37)}
#
# normalization...
# normalization done
# 1 1959
# 2 1249
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_386.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 35)}
#
# normalization...
# normalization done
# 1 1822
# 2 1902
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_351.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 48, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 48, 38)}
#
# normalization...
# normalization done
# 1 2123
# 2 1754
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_374.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 43, 47, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 43, 47, 34)}
#
# normalization...
# normalization done
# 1 1298
# 2 1295
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_336.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 51, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 51, 33)}
#
# normalization...
# normalization done
# 1 1509
# 2 1571
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_387.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 50, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 50, 36)}
#
# normalization...
# normalization done
# 1 1733
# 2 1372
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_361.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 38)}
#
# normalization...
# normalization done
# 1 1966
# 2 1713
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_352.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 54, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 54, 32)}
#
# normalization...
# normalization done
# 1 1686
# 2 1536
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_375.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 44, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 44, 33)}
#
# normalization...
# normalization done
# 1 1551
# 2 1702
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_337.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 52, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 52, 38)}
#
# normalization...
# normalization done
# 1 1838
# 2 1668
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_363.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 49, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 49, 34)}
#
# normalization...
# normalization done
# 1 1763
# 2 1184
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_389.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 31, 51, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 31, 51, 32)}
#
# normalization...
# normalization done
# 1 1415
# 2 1340
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_353.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 55, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 55, 35)}
#
# normalization...
# normalization done
# 1 1625
# 2 1956
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_376.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 43, 43, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 43, 43, 37)}
#
# normalization...
# normalization done
# 1 2007
# 2 1616
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_338.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 47, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 47, 37)}
#
# normalization...
# normalization done
# 1 2482
# 2 1497
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_366.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 51, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 51, 38)}
#
# normalization...
# normalization done
# 1 1886
# 2 1366
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_390.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 50, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 50, 36)}
#
# normalization...
# normalization done
# 1 1529
# 2 1383
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_354.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 52, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 52, 35)}
#
# normalization...
# normalization done
# 1 1180
# 2 1577
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_378.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 46, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 46, 35)}
#
# normalization...
# normalization done
# 1 1592
# 2 1618
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_340.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 57, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 57, 36)}
#
# normalization...
# normalization done
# 1 2212
# 2 1939
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_367.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 31, 51, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 31, 51, 36)}
#
# normalization...
# normalization done
# 1 1864
# 2 1818
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_393.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 47, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 47, 33)}
#
# normalization...
# normalization done
# 1 1819
# 2 1516
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_355.npz
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 42, 46, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 42, 46, 35)}
#
# normalization...
# normalization done
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 48, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 48, 34)}
#
# normalization...
# normalization done
# 1 1331
# 2 1257
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_341.npz
# 1 1730
# 2 1705
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_380.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 52, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 52, 36)}
#
# normalization...
# normalization done
# 1 1987
# 2 1827
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_394.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 55, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 55, 38)}
#
# normalization...
# normalization done
# 1 2593
# 2 1808
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_368.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 49, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 49, 33)}
#
# normalization...
# normalization done
# 1 1550
# 2 1602
# saving:  /content/drive/MyDrive/CardiacSeg/dataset/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_381.npz
